# %%
import numpy as np
import pandas as pd

train_ds = pd.read_csv('train.csv')
train_ds
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
gender_submission = pd.read_csv('gender_submission.csv')
gender_submission
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
train_ds['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
train_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train_ds_without_age = train_ds.dropna(axis=1)
train_ds_without_age
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch
# 0                              Braund, Mr. Owen Harris    male      1      0  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
train_ds_without_age.loc[:, 'Sex'] = train_ds_without_age['Sex'].replace({'male': 0, 'female': 1})

train_ds_without_age
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name Sex  SibSp  Parch
# 0                              Braund, Mr. Owen Harris   0      1      0  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...   1      1      0
# 2                               Heikkinen, Miss. Laina   1      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   1      1      0
# 4                             Allen, Mr. William Henry   0      0      0
# ..                                                 ...  ..    ...    ...
# ...

# %%
features_without_age = ['Pclass', 'Fare', 'Sex', 'SibSp', 'Parch']
y = train_ds_without_age.Survived

X = train_ds_without_age[features_without_age]

X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Pclass  891 non-null    int64
#  1   Fare    891 non-null    float64
#  2   Sex     891 non-null    object
#  3   SibSp   891 non-null    int64
#  4   Parch   891 non-null    int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 34.9+ KB

# %%
women = train_ds.loc[train_ds.Sex == 'female']["Survived"]
rate_women = sum(women)/len(women)

print("% of women who survived:", rate_women)
# Out:
# % of women who survived: 0.7420382165605095

# %%
men = train_ds.loc[train_ds.Sex == 'male']["Survived"]
rate_men = sum(men)/len(men)

print("% of men who survived:", rate_men)
# Out:
# % of men who survived: 0.18890814558058924

# %%
from sklearn.ensemble import RandomForestRegressor

titanic_model_without_age = RandomForestRegressor(random_state=1)
titanic_model_without_age.fit(X, y)
# Out:
# RandomForestRegressor(random_state=1)

# %%
from sklearn.model_selection import train_test_split

train_X, val_X, train_y, val_y = train_test_split(X, y, random_state=0)

titanic_model_without_age.fit(train_X, train_y)

titanic_pred = titanic_model_without_age.predict(val_X)
binary_predictions = [1 if p >= 0.5 else 0 for p in titanic_pred]

# %%
from sklearn.metrics import accuracy_score

titanic_accuracy_without_age_rf = accuracy_score(binary_predictions, val_y)
titanic_accuracy_without_age_rf
# Out:
# 0.8251121076233184

# %%
test_ds = pd.read_csv('test.csv')
test_ds.loc[:, 'Sex'] = test_ds['Sex'].replace({'male': 0, 'female': 1})
test_ds['Fare'] = test_ds['Fare'].fillna(8)
test_ds = test_ds.drop('Age', axis=1)
test_ds = test_ds.drop('Cabin', axis=1)
test_ds = test_ds.dropna()

# %%
row = list(test_ds['PassengerId'])
for i in range(len(row)-1):
    if row[i+1]-row[i] != 1:
        print('You delete one passenger', i)

# %%
test_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   SibSp        418 non-null    int64
#  5   Parch        418 non-null    int64
#  6   Ticket       418 non-null    object
#  7   Fare         418 non-null    float64
#  8   Embarked     418 non-null    object
# dtypes: float64(1), int64(4), object(4)
# memory usage: 29.5+ KB

# %%
X_test = test_ds[features_without_age]

titanic_pred_test = titanic_model_without_age.predict(X_test)
binary_predictions = [1 if p >= 0.5 else 0 for p in titanic_pred_test]

# %%
output = pd.DataFrame({'PassengerId': test_ds.PassengerId,
                       'Survived': binary_predictions})
output.to_csv('submission.csv', index=False)

# %%
sub = pd.read_csv('submission.csv')
sub
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]
