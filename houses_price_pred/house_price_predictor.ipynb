# %%
import pandas as pd
import numpy as np

house_data_train = pd.read_csv('train.csv')
house_data_train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg  \
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
with open('data_description.txt') as file:
    f = file.readlines()

f
# Out:
# ['MSSubClass: Identifies the type of dwelling involved in the sale.\t\n',
#  '\n',
#  '        20\t1-STORY 1946 & NEWER ALL STYLES\n',
#  '        30\t1-STORY 1945 & OLDER\n',
#  '        40\t1-STORY W/FINISHED ATTIC ALL AGES\n',
#  '        45\t1-1/2 STORY - UNFINISHED ALL AGES\n',
#  '        50\t1-1/2 STORY FINISHED ALL AGES\n',
#  '        60\t2-STORY 1946 & NEWER\n',
#  '        70\t2-STORY 1945 & OLDER\n',
#  '        75\t2-1/2 STORY ALL AGES\n',
#  '        80\tSPLIT OR MULTI-LEVEL\n',
#  '        85\tSPLIT FOYER\n',
#  '        90\tDUPLEX - ALL STYLES AND AGES\n',
#  '       120\t1-STORY PUD (Planned Unit Development) - 1946 & NEWER\n',
#  '       150\t1-1/2 STORY PUD - ALL AGES\n',
#  '       160\t2-STORY PUD - 1946 & NEWER\n',
#  '       180\tPUD - MULTILEVEL - INCL SPLIT LEV/FOYER\n',
#  '       190\t2 FAMILY CONVERSION - ALL STYLES AND AGES\n',
#  '\n',
#  'MSZoning: Identifies the general zoning classification of the sale.\n',
#  '\t\t\n',
#  '       A\tAgriculture\n',
# ...

# %%
house_data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
house_data_train['Alley'].unique()
# Out:
# array([nan, 'Grvl', 'Pave'], dtype=object)

# %%
house_data_train['Alley'] = house_data_train['Alley'].fillna(0)

# %%
house_data_train['MasVnrType'].unique()

# if MasVnrArea column contains 1452 elements, but MasVnrType contains only 588 elements we can assume that those houses don't contain masonry
# Out:
# array(['BrkFace', nan, 'Stone', 'BrkCmn'], dtype=object)

# %%
house_data_train.loc[house_data_train['MasVnrType'].isna(), 'MasVnrArea']
# Out:
# 1       0.0
# 3       0.0
# 5       0.0
# 8       0.0
# 9       0.0
#        ...
# 1454    0.0
# 1455    0.0
# 1457    0.0
# 1458    0.0
# 1459    0.0
# Name: MasVnrArea, Length: 872, dtype: float64

# %%
house_data_train['MasVnrType'] = house_data_train['MasVnrType'].fillna(0)

# %%
house_data_train['MasVnrArea'] = house_data_train['MasVnrArea'].fillna(0)

# %%
house_data_train['Electrical'].unique()
# Out:
# array(['SBrkr', 'FuseF', 'FuseA', 'FuseP', 'Mix'], dtype=object)

# %%
house_data_train['Electrical'] = house_data_train['Electrical'].fillna('Mix')

# %%
house_data_train['BsmtQual'].fillna(0 ,inplace=True)
house_data_train['BsmtCond'].fillna(0 ,inplace=True)
house_data_train['BsmtExposure'].fillna(0 ,inplace=True)
house_data_train['BsmtFinType1'].fillna(0 ,inplace=True)
house_data_train['BsmtFinType2'].fillna(0 ,inplace=True)

house_data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          1460 non-null   object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
house_data_train['LotFrontage'].unique()
# Out:
# array([ 65.,  80.,  68.,  60.,  84.,  85.,  75.,  nan,  51.,  50.,  70.,
#         91.,  72.,  66., 101.,  57.,  44., 110.,  98.,  47., 108., 112.,
#         74., 115.,  61.,  48.,  33.,  52., 100.,  24.,  89.,  63.,  76.,
#         81.,  95.,  69.,  21.,  32.,  78., 121., 122.,  40., 105.,  73.,
#         77.,  64.,  94.,  34.,  90.,  55.,  88.,  82.,  71., 120., 107.,
#         92., 134.,  62.,  86., 141.,  97.,  54.,  41.,  79., 174.,  99.,
#         67.,  83.,  43., 103.,  93.,  30., 129., 140.,  35.,  37., 118.,
#         87., 116., 150., 111.,  49.,  96.,  59.,  36.,  56., 102.,  58.,
#         38., 109., 130.,  53., 137.,  45., 106., 104.,  42.,  39., 144.,
#        114., 128., 149., 313., 168., 182., 138., 160., 152., 124., 153.,
#         46.])

# %%
mean_house_data_train_LotFrontage = house_data_train['LotFrontage'].mean()
house_data_train['LotFrontage'].fillna(mean_house_data_train_LotFrontage, inplace=True)

# %%
house_data_train['FireplaceQu'].fillna(0, inplace=True)

# %%
house_data_train['GarageType'].fillna(0, inplace=True)
house_data_train['GarageArea'].fillna(0, inplace=True)
house_data_train['GarageCars'].fillna(0, inplace=True)
house_data_train['GarageCond'].fillna(0, inplace=True)
house_data_train['GarageFinish'].fillna(0, inplace=True)
house_data_train['GarageQual'].fillna(0, inplace=True)
house_data_train['GarageYrBlt'].fillna(0, inplace=True)
house_data_train['PoolQC'].fillna(0, inplace=True)
house_data_train['Fence'].fillna(0, inplace=True)
house_data_train['MiscFeature'].fillna(0, inplace=True)

# %%
house_data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          1460 non-null   object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
categorical_cols = house_data_train.select_dtypes(include=['object']).columns

# apply one-hot encoding to each categorical variable
for col in categorical_cols:
    one_hot = pd.get_dummies(house_data_train[col], prefix=col)
    data = pd.concat([house_data_train, one_hot], axis=1)
    house_data_train.drop(col, axis=1, inplace=True)

# %%
house_data_train.head(10)
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt
# 0   1          60    65.000000     8450            7            5       2003  \
# 1   2          20    80.000000     9600            6            8       1976
# 2   3          60    68.000000    11250            7            5       2001
# 3   4          70    60.000000     9550            7            5       1915
# 4   5          60    84.000000    14260            8            5       2000
# 5   6          50    85.000000    14115            5            5       1993
# 6   7          20    75.000000    10084            8            5       2004
# 7   8          60    70.049958    10382            7            6       1973
# 8   9          50    51.000000     6120            7            5       1931
# 9  10         190    50.000000     7420            5            6       1939
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  OpenPorchSF
# ...

# %%
features = [col for col in house_data_train.columns if col not in ['Id', 'SaleType', 'SaleCondition', 'SalePrice']]

X = house_data_train[features]
y = house_data_train['SalePrice']

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

house_price_model_rfr = RandomForestRegressor(random_state=1)

train_X, val_X, train_y, val_y = train_test_split(X, y, random_state=0)
house_price_model_rfr.fit(train_X, train_y)

pred_house_price_model_rfr = house_price_model_rfr.predict(val_X)

r2_pred_house_price_model_rfr = r2_score(val_y, pred_house_price_model_rfr)

r2_pred_house_price_model_rfr
# Out:
# 0.855090179877958

# %%
house_data_test = pd.read_csv('test.csv')

house_data_test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg  \
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
house_data_test['Alley'].fillna(0, inplace=True)
house_data_test['Electrical'].fillna('Mix', inplace=True)
house_data_test['MasVnrType'].fillna(0, inplace=True)
house_data_test['MasVnrArea'].fillna(0, inplace=True)
house_data_test['BsmtQual'].fillna(0 ,inplace=True)
house_data_test['BsmtCond'].fillna(0 ,inplace=True)
house_data_test['BsmtExposure'].fillna(0 ,inplace=True)
house_data_test['BsmtFinType1'].fillna(0 ,inplace=True)
house_data_test['BsmtFinType2'].fillna(0 ,inplace=True)

mean_house_data_test_LotFrontage = house_data_test['LotFrontage'].mean()
house_data_test['LotFrontage'].fillna(mean_house_data_test_LotFrontage, inplace=True)

house_data_test['FireplaceQu'].fillna(0, inplace=True)

house_data_test['GarageType'].fillna(0, inplace=True)
house_data_test['GarageArea'].fillna(0, inplace=True)
house_data_test['GarageCars'].fillna(0, inplace=True)
house_data_test['GarageCond'].fillna(0, inplace=True)
house_data_test['GarageFinish'].fillna(0, inplace=True)
house_data_test['GarageQual'].fillna(0, inplace=True)
house_data_test['GarageYrBlt'].fillna(0, inplace=True)
house_data_test['PoolQC'].fillna(0, inplace=True)
house_data_test['Fence'].fillna(0, inplace=True)
house_data_test['MiscFeature'].fillna(0, inplace=True)

# %%
house_data_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1459 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   Alley          1459 non-null   object
#  7   LotShape       1459 non-null   object
#  8   LandContour    1459 non-null   object
#  9   Utilities      1457 non-null   object
#  10  LotConfig      1459 non-null   object
#  11  LandSlope      1459 non-null   object
#  12  Neighborhood   1459 non-null   object
#  13  Condition1     1459 non-null   object
#  14  Condition2     1459 non-null   object
#  15  BldgType       1459 non-null   object
#  16  HouseStyle     1459 non-null   object
# ...

# %%
house_data_test['Utilities'].unique()
# Out:
# array(['AllPub', nan], dtype=object)

# %%
house_data_test['Utilities'].fillna('AllPub', inplace=True)

# %%
house_data_test['KitchenQual'].unique()
# Out:
# array(['TA', 'Gd', 'Ex', 'Fa', nan], dtype=object)

# %%
house_data_test['KitchenQual'].value_counts()
# Out:
# KitchenQual
# TA    757
# Gd    565
# Ex    105
# Fa     31
# Name: count, dtype: int64

# %%
house_data_test['KitchenQual'].fillna('TA', inplace=True)

# %%
house_data_test['Functional'].unique()
# Out:
# array(['Typ', 'Min2', 'Min1', 'Mod', 'Maj1', 'Sev', 'Maj2', nan],
#       dtype=object)

# %%
house_data_test['Functional'].value_counts()
# Out:
# Functional
# Typ     1357
# Min2      36
# Min1      34
# Mod       20
# Maj1       5
# Maj2       4
# Sev        1
# Name: count, dtype: int64

# %%
house_data_test['Functional'].fillna('Typ', inplace=True)

# %%
house_data_test['SaleType'].value_counts()
# Out:
# SaleType
# WD       1258
# New       117
# COD        44
# ConLD      17
# CWD         8
# Oth         4
# ConLI       4
# Con         3
# ConLw       3
# Name: count, dtype: int64

# %%
house_data_test['SaleType'].fillna('WD', inplace=True)

# %%
for col in house_data_test.columns:
    house_data_test[col].fillna(0, inplace=True)

# %%
house_data_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1459 non-null   object
#  3   LotFrontage    1459 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   Alley          1459 non-null   object
#  7   LotShape       1459 non-null   object
#  8   LandContour    1459 non-null   object
#  9   Utilities      1459 non-null   object
#  10  LotConfig      1459 non-null   object
#  11  LandSlope      1459 non-null   object
#  12  Neighborhood   1459 non-null   object
#  13  Condition1     1459 non-null   object
#  14  Condition2     1459 non-null   object
#  15  BldgType       1459 non-null   object
#  16  HouseStyle     1459 non-null   object
# ...

# %%
categorical_cols = house_data_test.select_dtypes(include=['object']).columns

# apply one-hot encoding to each categorical variable
for col in categorical_cols:
    one_hot = pd.get_dummies(house_data_test[col], prefix=col)
    data = pd.concat([house_data_test, one_hot], axis=1)
    house_data_test.drop(col, axis=1, inplace=True)

# %%
features = [col for col in house_data_test.columns if col not in ['Id', 'SaleType', 'SaleCondition', 'SalePrice']]

X_test = house_data_test[features]

# %%
pred_house_price_model_rfr_test = house_price_model_rfr.predict(X_test)

output = pd.DataFrame({'Id': house_data_test.Id,
                       'SalePrice': pred_house_price_model_rfr_test})
output.to_csv('submission_houses_price.csv', index=False)
